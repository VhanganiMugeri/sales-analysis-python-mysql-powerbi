# %% [markdown]
# ##Problem statement

# %% [markdown]
# #Problem Statement
#
# 1.  Neba Company
#
# *  Sales team Often lacks a clear, dara-driven understanding of regional performance, making it difficult to identify growth opportunities and optimize resources. this project Aims to Analyze and visualize regional sales data to uncover trends , evaluate profitability and support decision making

# %%
#importing libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1572069159.py in <cell line: 0>()
# ----> 1 sheets
#
# NameError: name 'sheets' is not defined

# %%
sheets = pd.read_excel('/Regional Sales Dataset (1).xlsx' , sheet_name= None)

# %%
sheets
# Out:
# {'Sales Orders':         OrderNumber  OrderDate  Customer Name Index      Channel  \
#  0       SO - 000225 2014-01-01                  126    Wholesale
#  1      SO - 0003378 2014-01-01                   96  Distributor
#  2      SO - 0005126 2014-01-01                    8    Wholesale
#  3      SO - 0005614 2014-01-01                   42       Export
#  4      SO - 0005781 2014-01-01                   73    Wholesale
#  ...             ...        ...                  ...          ...
#  64099  SO - 0007573 2018-02-28                   74    Wholesale
#  64100  SO - 0007706 2018-02-28                   51       Export
#  64101  SO - 0007718 2018-02-28                  136  Distributor
#  64102  SO - 0008084 2018-02-28                  158  Distributor
#  64103  SO - 0008654 2018-02-28                   22  Distributor
#
#        Currency Code Warehouse Code  Delivery Region Index  \
#  0               USD         AXW291                    364
# ...

# %%
#Assign dataframes to each sheet

df_sales = sheets['Sales Orders']
df_customers =sheets['Customers']
df_products =sheets['Products']
df_regions = sheets['Regions']
df_state_reg = sheets['State Regions']
df_budgets = sheets['2017 Budgets']

# %%
df_sales.head
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2958371275.py in <cell line: 0>()
# ----> 1 df_sales.head
#
# NameError: name 'df_sales' is not defined

# %%
df_sales.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-388599063.py in <cell line: 0>()
# ----> 1 df_sales.shape
#
# NameError: name 'df_sales' is not defined

# %%
print("df_sales shape: ", (df_sales.shape))
print("df_customers shape: ", (df_customers.shape))
print("df_products shape: ", (df_products.shape))
print("df_regions shape: ", (df_regions.shape))
print("df_state_reg: ", (df_state_reg.shape))
print("df_budgets shape: ", (df_budgets.shape))
# Out:
# df_sales shape:  (64104, 12)
# df_customers shape:  (175, 2)
# df_products shape:  (30, 2)
# df_regions shape:  (994, 15)
# df_state_reg:  (49, 3)
# df_budgets shape:  (30, 2)

# %%
print("df_sales : ", (df_sales.head))
print("df_customers shape: ", (df_customers.head))
print("df_products shape: ", (df_products.head))
print("df_regions shape: ", (df_regions.head))
print("df_state_reg: ", (df_state_reg.head))
print("df_budgets shape: ", (df_budgets.head))
# Out:
# df_sales :  <bound method NDFrame.head of         OrderNumber  OrderDate  Customer Name Index      Channel  \
# 0       SO - 000225 2014-01-01                  126    Wholesale
# 1      SO - 0003378 2014-01-01                   96  Distributor
# 2      SO - 0005126 2014-01-01                    8    Wholesale
# 3      SO - 0005614 2014-01-01                   42       Export
# 4      SO - 0005781 2014-01-01                   73    Wholesale
# ...             ...        ...                  ...          ...
# 64099  SO - 0007573 2018-02-28                   74    Wholesale
# 64100  SO - 0007706 2018-02-28                   51       Export
# 64101  SO - 0007718 2018-02-28                  136  Distributor
# 64102  SO - 0008084 2018-02-28                  158  Distributor
# 64103  SO - 0008654 2018-02-28                   22  Distributor
#
#       Currency Code Warehouse Code  Delivery Region Index  \
# 0               USD         AXW291                    364
# ...

# %%
df_sales.head(5)
# Out:
#     OrderNumber  OrderDate  Customer Name Index      Channel Currency Code  \
# 0   SO - 000225 2014-01-01                  126    Wholesale           USD
# 1  SO - 0003378 2014-01-01                   96  Distributor           USD
# 2  SO - 0005126 2014-01-01                    8    Wholesale           USD
# 3  SO - 0005614 2014-01-01                   42       Export           USD
# 4  SO - 0005781 2014-01-01                   73    Wholesale           USD
#
#   Warehouse Code  Delivery Region Index  Product Description Index  \
# 0         AXW291                    364                         27
# 1         AXW291                    488                         20
# 2         AXW291                    155                         26
# 3         AXW291                    473                          7
# 4         AXW291                    256                          8
#
#    Order Quantity  Unit Price  Line Total  Total Unit Cost
# ...

# %%
df_customers.head(5)
# Out:
#    Customer Index Customer Names
# 0               1  Geiss Company
# 1               2  Jaxbean Group
# 2               3     Ascend Ltd
# 3               4      Eire Corp
# 4               5   Blogtags Ltd

# %%
df_state_reg.head(5)
# Out:
#       Column1     Column2 Column3
# 0  State Code       State  Region
# 1          AL     Alabama   South
# 2          AR    Arkansas   South
# 3          AZ     Arizona    West
# 4          CA  California    West

# %%
new_header= df_state_reg.iloc[0]
df_state_reg.columns=new_header
df_state_reg= df_state_reg[1:].reset_index(drop=True)

df_state_reg.head(5)
# Out:
# 0 State Code       State Region
# 0         AL     Alabama  South
# 1         AR    Arkansas  South
# 2         AZ     Arizona   West
# 3         CA  California   West
# 4         CO    Colorado   West

# %%
df_budgets.head(5)
# Out:
#   Product Name  2017 Budgets
# 0    Product 1   3016489.209
# 1    Product 2   3050087.565
# 2    Product 3   2642352.432
# 3    Product 4   2885560.824
# 4    Product 5   3925424.542

# %%
df_regions.head(5)
# Out:
#    id        name                                   county state_code  \
# 0   1      Auburn                               Lee County         AL
# 1   2  Birmingham           Shelby County/Jefferson County         AL
# 2   3     Decatur           Limestone County/Morgan County         AL
# 3   4      Dothan  Dale County/Houston County/Henry County         AL
# 4   5      Hoover           Shelby County/Jefferson County         AL
#
#      state  type  latitude  longitude  area_code  population  households  \
# 0  Alabama  City  32.60986  -85.48078        334       62059       21767
# 1  Alabama  City  33.52744  -86.79905        205      212461       89972
# 2  Alabama  City  34.57332  -86.99214        256       55437       22294
# 3  Alabama  City  31.23370  -85.40682        334       68567       25913
# 4  Alabama  City  33.37695  -86.80558        205       84848       32789
#
#    median_income  land_area  water_area        time_zone
# ...

# %%
df_sales.isnull.sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-2779532288.py in <cell line: 0>()
# ----> 1 df_sales.isnull.sum()
#
# AttributeError: 'function' object has no attribute 'sum'

# %%
df_sales.isnull().sum()
# Out:
# OrderNumber                  0
# OrderDate                    0
# Customer Name Index          0
# Channel                      0
# Currency Code                0
# Warehouse Code               0
# Delivery Region Index        0
# Product Description Index    0
# Order Quantity               0
# Unit Price                   0
# Line Total                   0
# Total Unit Cost              0
# dtype: int64

# %%
df_products.isnull().sum()
# Out:
# Index           0
# Product Name    0
# dtype: int64

# %%
df_customers .isnull().sum()
# Out:
# Customer Index    0
# Customer Names    0
# dtype: int64

# %%
df_regions.isnull().sum()
# Out:
# id               0
# name             0
# county           0
# state_code       0
# state            0
# type             0
# latitude         0
# longitude        0
# area_code        0
# population       0
# households       0
# median_income    0
# land_area        0
# water_area       0
# time_zone        0
# dtype: int64

# %%
df_state_reg.isnull().sum()
# Out:
# 0
# State Code    0
# State         0
# Region        0
# dtype: int64

# %%
df_budgets.isnull().sum()
# Out:
# Product Name    0
# 2017 Budgets    0
# dtype: int64
